# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshal123/Introduction-To-Tensorflow/blob/main/Boston_housing_price_dataset_using_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split

tf.__version__
# Out:
# '2.4.1'

# %%
(X_train,y_train),(X_test,y_test) = tf.keras.datasets.boston_housing.load_data(
    path='boston_housing.npz', test_split=0.2, seed=113
)

# %%
# Generating the shape of the input data
X_train.shape,y_train.shape
# Out:
# ((404, 13), (404,))

# %%
# Create the Model
tf.random.set_seed(42)
model_1 = tf.keras.Sequential([
              tf.keras.layers.Dense(13),
              tf.keras.layers.Dense(100),
              tf.keras.layers.Dense(100),
              tf.keras.layers.Dense(1)
])

# Compile the Model

model_1.compile(loss = tf.keras.losses.mae,
                optimizer = tf.keras.optimizers.Adam(lr=0.1),
                metrics = ["mae"])

#Fit the Model

history = model_1.fit(X_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 1s 2ms/step - loss: 4977.2154 - mae: 4977.2154
# Epoch 2/200
# 13/13 [==============================] - 0s 3ms/step - loss: 423.6046 - mae: 423.6046
# Epoch 3/200
# 13/13 [==============================] - 0s 2ms/step - loss: 630.5733 - mae: 630.5733
# Epoch 4/200
# 13/13 [==============================] - 0s 2ms/step - loss: 181.9225 - mae: 181.9225
# Epoch 5/200
# 13/13 [==============================] - 0s 2ms/step - loss: 51.2877 - mae: 51.2877
# Epoch 6/200
# 13/13 [==============================] - 0s 2ms/step - loss: 17.8222 - mae: 17.8222
# Epoch 7/200
# 13/13 [==============================] - 0s 2ms/step - loss: 13.1591 - mae: 13.1591
# Epoch 8/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.0013 - mae: 10.0013
# Epoch 9/200
# 13/13 [==============================] - 0s 2ms/step - loss: 6.9663 - mae: 6.9663
# Epoch 10/200
# ...

# %%
# Evaluate the Data

model_1.evaluate(X_test,y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 5.4674 - mae: 5.4674
# [5.467385292053223, 5.467385292053223]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-d70db719728f> in <module>()
# ----> 1 model_1.accuracy(X_test,y_test)
#
# AttributeError: 'Sequential' object has no attribute 'accuracy'
